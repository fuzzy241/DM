# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
summer_data = pd.read_csv('C:/Users/farazkhan/Desktop/Indian Summers_DM_LAB.csv')

# %%
summer_data.head()
# Out:
#     City        Date  tempmax  tempmin  temp  feelslikemax  feelslikemin  \
# 0  Surat  01-04-2011     32.7     21.1  27.1          33.4          21.1
# 1  Surat  02-04-2011     32.4     25.0  27.1          34.7          25.0
# 2  Surat  03-04-2011     31.7     23.4  27.0          32.9          23.4
# 3  Surat  04-04-2011     35.9     20.1  27.5          33.4          20.1
# 4  Surat  05-04-2011     35.4     21.2  28.4          34.0          21.2
#
#    feelslike   dew  humidity  windspeed  winddir  sealevelpressure  \
# 0       27.9  19.1      62.6       26.3    271.0            1010.9
# 1       27.8  21.3      71.7       25.6    250.3            1010.3
# 2       27.4  19.7      66.1       22.3    261.9            1010.5
# 3       27.3  16.1      54.6       20.5    231.2            1010.1
# 4       28.4  17.0      52.7       22.7    226.0            1010.0
#
#    cloudcover  visibility           sunrise            sunset  moonphase  \
# 0         0.0         4.0  01-04-2011 06:32  01-04-2011 18:53       0.99
# 1         0.0         3.5  02-04-2011 06:31  02-04-2011 18:53       1.00
# 2         0.0         4.0  03-04-2011 06:30  03-04-2011 18:53       1.00
# 3         0.0         4.0  04-04-2011 06:29  04-04-2011 18:54       0.00
# 4         2.4         4.0  05-04-2011 06:28  05-04-2011 18:54       0.02
#
#   conditions                           description
# 0      Clear  Clear conditions throughout the day.
# 1      Clear  Clear conditions throughout the day.
# 2      Clear  Clear conditions throughout the day.
# 3      Clear  Clear conditions throughout the day.
# 4      Clear  Clear conditions throughout the day.

# %%
summer_data.tail()
# Out:
#            City        Date  tempmax  tempmin  temp  feelslikemax  \
# 6727  Hyderabad  26-06-2007     29.1     23.1  26.5          30.9
# 6728  Hyderabad  27-06-2007     29.1     24.1  26.3          32.9
# 6729  Hyderabad  28-06-2007     29.1     25.1  26.8          31.4
# 6730  Hyderabad  29-06-2007     27.1     24.1  26.2          28.6
# 6731  Hyderabad  30-06-2007     28.1     24.1  26.2          29.3
#
#       feelslikemin  feelslike   dew  humidity  windspeed  winddir  \
# 6727          23.1       27.6  21.3     73.67       24.1      NaN
# 6728          24.1       27.3  21.4     74.96       27.7      NaN
# 6729          25.1       27.7  20.6     69.17       27.7      NaN
# 6730          24.1       26.9  20.3     70.24       25.9      NaN
# 6731          24.1       26.9  20.3     70.43       25.9      NaN
#
#       sealevelpressure  cloudcover  visibility           sunrise  \
# 6727               NaN        97.6         3.4  26-06-2007 05:43
# 6728               NaN        93.8         4.3  27-06-2007 05:44
# 6729               NaN        93.8         4.6  28-06-2007 05:44
# 6730               NaN        98.8         5.0  29-06-2007 05:44
# 6731               NaN        96.8         4.5  30-06-2007 05:44
#
#                 sunset  moonphase      conditions  \
# 6727  26-06-2007 18:53       0.42  Rain, Overcast
# 6728  27-06-2007 18:53       0.45  Rain, Overcast
# 6729  28-06-2007 18:54       0.48  Rain, Overcast
# 6730  29-06-2007 18:54       0.49  Rain, Overcast
# 6731  30-06-2007 18:54       0.50  Rain, Overcast
#
#                                             description
# 6727  Cloudy skies throughout the day with afternoon...
# 6728         Cloudy skies throughout the day with rain.
# 6729  Cloudy skies throughout the day with late afte...
# 6730         Cloudy skies throughout the day with rain.
# 6731  Cloudy skies throughout the day with late afte...

# %%
summer_data.shape
# Out:
# (6732, 20)

# %%
summer_data.columns
# Out:
# Index(['City', 'Date', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'windspeed', 'winddir',
#        'sealevelpressure', 'cloudcover', 'visibility', 'sunrise', 'sunset',
#        'moonphase', 'conditions', 'description'],
#       dtype='object')

# %%
summer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6732 entries, 0 to 6731
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   City              6732 non-null   object
#  1   Date              6732 non-null   object
#  2   tempmax           6729 non-null   float64
#  3   tempmin           6729 non-null   float64
#  4   temp              6729 non-null   float64
#  5   feelslikemax      6729 non-null   float64
#  6   feelslikemin      6729 non-null   float64
#  7   feelslike         6729 non-null   float64
#  8   dew               6729 non-null   float64
#  9   humidity          6729 non-null   float64
#  10  windspeed         6729 non-null   float64
#  11  winddir           5361 non-null   float64
#  12  sealevelpressure  2535 non-null   float64
#  13  cloudcover        6729 non-null   float64
#  14  visibility        6697 non-null   float64
#  15  sunrise           6732 non-null   object
#  16  sunset            6732 non-null   object
#  17  moonphase         6732 non-null   float64
#  18  conditions        6729 non-null   object
#  19  description       6729 non-null   object
# dtypes: float64(14), object(6)
# memory usage: 1.0+ MB

# %%
summer_data.describe()
# Out:
#            tempmax      tempmin         temp  feelslikemax  feelslikemin  \
# count  6729.000000  6729.000000  6729.000000   6729.000000   6729.000000
# mean     36.776891    25.759058    30.980265     39.527968     26.928697
# std       4.083612     2.976657     2.986435      4.852376      4.413873
# min      23.100000    13.200000    21.300000     23.100000     13.200000
# 25%      33.700000    23.800000    29.100000     36.300000     23.800000
# 50%      37.100000    26.100000    31.000000     39.400000     26.100000
# 75%      40.100000    28.100000    33.000000     42.700000     30.200000
# max      49.100000    36.100000    41.400000     59.900000     41.500000
#
#         feelslike          dew     humidity    windspeed      winddir  \
# count  6729.00000  6729.000000  6729.000000  6729.000000  5361.000000
# mean     33.08658    18.395408    53.451623    21.622128   218.309569
# std       4.22803     6.151566    19.796179     8.446463    64.518685
# min      21.30000    -4.700000     9.930000     0.000000    23.200000
# 25%      30.10000    14.400000    36.600000    16.400000   173.500000
# 50%      33.20000    19.500000    54.200000    22.300000   233.300000
# 75%      36.20000    23.500000    70.800000    25.900000   270.700000
# max      47.90000    27.900000    97.700000   161.300000   360.000000
#
#        sealevelpressure   cloudcover   visibility    moonphase
# count       2535.000000  6729.000000  6697.000000  6732.000000
# mean        1003.510454    39.825873     4.805674     0.512240
# std            4.110719    27.066293     1.443592     0.302873
# min          946.600000     0.000000     1.600000     0.000000
# 25%         1000.800000    16.400000     4.000000     0.280000
# 50%         1003.800000    38.800000     4.500000     0.500000
# 75%         1006.600000    60.000000     5.700000     0.760000
# max         1017.100000   100.000000    10.500000     1.000000

# %%
summer_data.isnull().sum()
# Out:
# City                   0
# Date                   0
# tempmax                3
# tempmin                3
# temp                   3
# feelslikemax           3
# feelslikemin           3
# feelslike              3
# dew                    3
# humidity               3
# windspeed              3
# winddir             1371
# sealevelpressure    4197
# cloudcover             3
# visibility            35
# sunrise                0
# sunset                 0
# moonphase              0
# conditions             3
# description            3
# dtype: int64

# %%
summer_data=summer_data.drop(['sealevelpressure'],axis=1)

# %%
summer_data.columns
# Out:
# Index(['City', 'Date', 'tempmax', 'tempmin', 'temp', 'feelslikemax',
#        'feelslikemin', 'feelslike', 'dew', 'humidity', 'windspeed', 'winddir',
#        'cloudcover', 'visibility', 'sunrise', 'sunset', 'moonphase',
#        'conditions', 'description'],
#       dtype='object')

# %%
summer_data.dropna(inplace=True)

# %%
summer_data.shape
# Out:
# (5329, 19)

# %%
summer_data['conditions'].unique()
# Out:
# array(['Clear', 'Partially cloudy', 'Rain, Partially cloudy', 'Rain',
#        'Rain, Overcast', 'Overcast'], dtype=object)

# %%
summer_data['conditions'].value_counts()
# Out:
# Partially cloudy          2590
# Clear                     1558
# Rain, Partially cloudy    1020
# Rain, Overcast              80
# Overcast                    50
# Rain                        31
# Name: conditions, dtype: int64

# %%
plt.figure(figsize=(15,6))
sns.countplot('conditions', data = summer_data, palette='hls')
plt.xticks(rotation = 90)
plt.show()

# %%
count_clear=len(summer_data[summer_data.conditions=="Clear"])
count_pcloudy=len(summer_data[summer_data.conditions=="Partially cloudy"])
count_rpcloudy=len(summer_data[summer_data.conditions=="Rain, Partially cloudy"])
count_ro=len(summer_data[summer_data.conditions=="Rain, Overcast"])
count_overcast=len(summer_data[summer_data.conditions=="Overcast"])
count_rain=len(summer_data[summer_data.conditions=="Rain"])

# %%
print("Percent of Clear:{:2f}%".format((count_clear/(len(summer_data.conditions))*100)))
print("Percent of Partial Cloudy:{:2f}%".format((count_pcloudy/(len(summer_data.conditions))*100)))
print("Percent of Rain Partial Cloudy:{:2f}%".format((count_rpcloudy/(len(summer_data.conditions))*100)))
print("Percent of Rain Overcast:{:2f}%".format((count_ro/(len(summer_data.conditions))*100)))
print("Percent of Overcast:{:2f}%".format((count_overcast/(len(summer_data.conditions))*100)))
print("Percent of Rain:{:2f}%".format((count_rain/(len(summer_data.conditions))*100)))
# Out:
# Percent of Clear:29.236254%
# Percent of Partial Cloudy:48.601989%
# Percent of Rain Partial Cloudy:19.140552%
# Percent of Rain Overcast:1.501220%
# Percent of Overcast:0.938262%
# Percent of Rain:0.581723%

# %%
summer_data[["humidity","tempmax","tempmin","windspeed"]].describe()
# Out:
#           humidity      tempmax      tempmin    windspeed
# count  5329.000000  5329.000000  5329.000000  5329.000000
# mean     53.060184    36.803528    25.692119    22.045637
# std      20.125284     4.094303     3.022720     8.214729
# min       9.930000    25.400000    13.200000     3.600000
# 25%      35.900000    33.700000    23.500000    16.600000
# 50%      53.900000    37.100000    26.100000    22.300000
# 75%      70.820000    40.100000    28.100000    25.900000
# max      97.700000    48.100000    36.100000   161.300000

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=summer_data,x="humidity",kde=True,ax=axs[0,0],color='green')
sns.histplot(data=summer_data,x="tempmax",kde=True,ax=axs[0,1],color='red')
sns.histplot(data=summer_data,x="tempmin",kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=summer_data,x="windspeed",kde=True,ax=axs[1,1],color='orange')
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='Count'>

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.violinplot(data=summer_data,x="humidity",kde=True,ax=axs[0,0],color='green')
sns.violinplot(data=summer_data,x="tempmax",kde=True,ax=axs[0,1],color='red')
sns.violinplot(data=summer_data,x="tempmin",kde=True,ax=axs[1,0],color='skyblue')
sns.violinplot(data=summer_data,x="windspeed",kde=True,ax=axs[1,1],color='yellow')
# Out:
# <AxesSubplot:xlabel='windspeed'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot("humidity","conditions",data=summer_data,palette="YlOrBr")
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='conditions'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot("tempmax","conditions",data=summer_data,palette="inferno")
# Out:
# <AxesSubplot:xlabel='tempmax', ylabel='conditions'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot("windspeed","conditions",data=summer_data,palette="inferno")
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='conditions'>

# %%
plt.figure(figsize=(12,6))
sns.boxplot("tempmin","conditions",data=summer_data,palette="inferno")
# Out:
# <AxesSubplot:xlabel='tempmin', ylabel='conditions'>

# %%
plt.figure(figsize=(12,7))
sns.heatmap(summer_data.corr(),annot=True,cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
from scipy import stats

# %%
summer_data.plot("humidity","tempmax",style='o')
print("Pearson correlation:",summer_data["humidity"].corr(summer_data["tempmax"]))
print("T Test and P value:",stats.ttest_ind(summer_data["humidity"],summer_data["tempmax"]))
# Out:
# Pearson correlation: -0.7407725574765172
# T Test and P value: Ttest_indResult(statistic=57.78375421082535, pvalue=0.0)

# %%
summer_data.plot("windspeed","tempmax",style='o')
print("Pearson correlation:",summer_data["windspeed"].corr(summer_data["tempmax"]))
print("T Test and P value:",stats.ttest_ind(summer_data["windspeed"],summer_data["tempmax"]))
# Out:
# Pearson correlation: 0.014101479891436982
# T Test and P value: Ttest_indResult(statistic=-117.37479205737073, pvalue=0.0)

# %%
summer_data.plot("tempmin","tempmax",style='o')
print("Pearson correlation:",summer_data["tempmin"].corr(summer_data["tempmax"]))
print("T Test and P value:",stats.ttest_ind(summer_data["tempmin"],summer_data["tempmax"]))
# Out:
# Pearson correlation: 0.35650024711546735
# T Test and P value: Ttest_indResult(statistic=-159.38257092916393, pvalue=0.0)

# %%
df=summer_data.drop(['Date', 'sunrise', 'sunset', 'description'],axis=1)

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df.humidity=np.sqrt(df.humidity)
df.windspeed=np.sqrt(df.windspeed)

# %%
sns.set(style="darkgrid")
fig,axs=plt.subplots(2,2,figsize=(10,8))
sns.histplot(data=df,x="humidity",kde=True,ax=axs[0,0],color='green')
sns.histplot(data=df,x="tempmax",kde=True,ax=axs[0,1],color='red')
sns.histplot(data=df,x="tempmin",kde=True,ax=axs[1,0],color='skyblue')
sns.histplot(data=df,x="windspeed",kde=True,ax=axs[1,1],color='orange')
# Out:
# <AxesSubplot:xlabel='windspeed', ylabel='Count'>

# %%
df.head()
# Out:
#     City  tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0  Surat     32.7     21.1  27.1          33.4          21.1       27.9  19.1
# 1  Surat     32.4     25.0  27.1          34.7          25.0       27.8  21.3
# 2  Surat     31.7     23.4  27.0          32.9          23.4       27.4  19.7
# 3  Surat     35.9     20.1  27.5          33.4          20.1       27.3  16.1
# 4  Surat     35.4     21.2  28.4          34.0          21.2       28.4  17.0
#
#    humidity  windspeed  winddir  cloudcover  visibility  moonphase conditions
# 0  7.912016   5.128353    271.0         0.0         4.0       0.99      Clear
# 1  8.467585   5.059644    250.3         0.0         3.5       1.00      Clear
# 2  8.130191   4.722288    261.9         0.0         4.0       1.00      Clear
# 3  7.389181   4.527693    231.2         0.0         4.0       0.00      Clear
# 4  7.259477   4.764452    226.0         2.4         4.0       0.02      Clear

# %%
df1 = df.drop(['City'], axis = 1)

# %%
df1.head()
# Out:
#    tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0     32.7     21.1  27.1          33.4          21.1       27.9  19.1
# 1     32.4     25.0  27.1          34.7          25.0       27.8  21.3
# 2     31.7     23.4  27.0          32.9          23.4       27.4  19.7
# 3     35.9     20.1  27.5          33.4          20.1       27.3  16.1
# 4     35.4     21.2  28.4          34.0          21.2       28.4  17.0
#
#    humidity  windspeed  winddir  cloudcover  visibility  moonphase conditions
# 0  7.912016   5.128353    271.0         0.0         4.0       0.99      Clear
# 1  8.467585   5.059644    250.3         0.0         3.5       1.00      Clear
# 2  8.130191   4.722288    261.9         0.0         4.0       1.00      Clear
# 3  7.389181   4.527693    231.2         0.0         4.0       0.00      Clear
# 4  7.259477   4.764452    226.0         2.4         4.0       0.02      Clear

# %%
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
lc=LabelEncoder()
df1["conditions"]=lc.fit_transform(df1["conditions"])

# %%
df1.head()
# Out:
#    tempmax  tempmin  temp  feelslikemax  feelslikemin  feelslike   dew  \
# 0     32.7     21.1  27.1          33.4          21.1       27.9  19.1
# 1     32.4     25.0  27.1          34.7          25.0       27.8  21.3
# 2     31.7     23.4  27.0          32.9          23.4       27.4  19.7
# 3     35.9     20.1  27.5          33.4          20.1       27.3  16.1
# 4     35.4     21.2  28.4          34.0          21.2       28.4  17.0
#
#    humidity  windspeed  winddir  cloudcover  visibility  moonphase  conditions
# 0  7.912016   5.128353    271.0         0.0         4.0       0.99           0
# 1  8.467585   5.059644    250.3         0.0         3.5       1.00           0
# 2  8.130191   4.722288    261.9         0.0         4.0       1.00           0
# 3  7.389181   4.527693    231.2         0.0         4.0       0.00           0
# 4  7.259477   4.764452    226.0         2.4         4.0       0.02           0

# %%
x=((df1.loc[:,df1.columns!="conditions"]).astype(int)).values[:,0:]
y=df1["conditions"].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=2)

# %%
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
print("KNN Accuracy:{:.2f}%".format(knn.score(x_test,y_test)*100))
# Out:
# KNN Accuracy:77.46%

# %%
svm=SVC()
svm.fit(x_train,y_train)
print("SVM Accuracy:{:.2f}%".format(svm.score(x_test,y_test)*100))
# Out:
# SVM Accuracy:79.34%

# %%
gbc=GradientBoostingClassifier(subsample=0.5,n_estimators=450,max_depth=5,max_leaf_nodes=5)
gbc.fit(x_train,y_train)
print("Gradient Boosting Accuracy:{:.2f}%".format(gbc.score(x_test,y_test)*100))
# Out:
# Gradient Boosting Accuracy:80.93%
